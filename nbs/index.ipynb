# %% [markdown]
# # cjm-fasthtml-workflow-transcription-single-file
#
# > A self-contained workflow for single-file transcription in FastHTML applications.

# %% [markdown]
# ## Install
#
# ```bash
# pip install cjm_fasthtml_workflow_transcription_single_file
# ```
